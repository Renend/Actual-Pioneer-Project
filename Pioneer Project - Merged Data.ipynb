# %%
# !pip install ydata-profiling

# %%
import pandas as pd
import ydata_profiling

df = pd.read_csv('Merged Dataset - Freedom and SAT - Sheet1.csv')
pr = df.profile_report()
pr
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.7.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-06-25 14:20:49.525264&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Year                    11 non-null     int64
#  1   Math                    11 non-null     int64
#  2   Reading                 11 non-null     int64
#  3   Writing                 4 non-null      float64
#  4   Total (Math + Reading)  11 non-null     int64
#  5   PR rating               11 non-null     int64
#  6   CL rating               11 non-null     int64
#  7   A                       11 non-null     int64
#  8   B                       11 non-null     int64
#  9   C                       11 non-null     int64
#  10  PR                      11 non-null     int64
#  11  D                       11 non-null     int64
#  12  E                       11 non-null     int64
#  13  F                       11 non-null     int64
# ...

# %%
df.describe()
# Out:
#               Year        Math     Reading     Writing  \
# count    11.000000   11.000000   11.000000    4.000000
# mean   2018.000000  520.181818  517.454545  485.250000
# std       3.316625    9.389549   17.873800    2.753785
# min    2013.000000  508.000000  494.000000  482.000000
# 25%    2015.500000  512.000000  496.500000  483.500000
# 50%    2018.000000  523.000000  528.000000  485.500000
# 75%    2020.500000  528.000000  532.000000  487.250000
# max    2023.000000  531.000000  536.000000  488.000000
#
#        Total (Math + Reading)  PR rating  CL rating          A          B  \
# count               11.000000  11.000000  11.000000  11.000000  11.000000
# mean              1037.636364   1.545455   1.272727  10.454545  14.545455
# std                 26.333525   0.522233   0.467099   0.522233   1.035725
# min               1002.000000   1.000000   1.000000  10.000000  13.000000
# 25%               1010.000000   1.000000   1.000000  10.000000  14.000000
# ...

# %% [markdown]
# # EDA
# ## Bivariate Analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import style

plt.scatter(df['CL rating'], df['Total (Math + Reading)'])
plt.show()

# %%
plt.scatter(df['PR rating'], df['Total (Math + Reading)'])
plt.show()

# %%
plt.scatter(df['D'], df['Total (Math + Reading)'])
plt.show()

# %%
plt.scatter(df['E'], df['Total (Math + Reading)'])
plt.show()

# %%
plt.scatter(df['G'], df['Total (Math + Reading)'])
plt.show()

# %%
plt.scatter(df['CL'], df['Total (Math + Reading)'])
plt.show()

# %%
plt.scatter(df['Total'], df['Total (Math + Reading)'])
plt.show()

# %% [markdown]
# ## Multivariate Analysis

# %%
import numpy as np
# %matplotlib inline

plt.figure(figsize=(10,5))
var = ['Math', 'Reading', 'Total (Math + Reading)', 'PR rating', 'CL rating', 'A', 'B', 'C', 'D', 'E', 'F', 'G']
data = df[var]
sns.heatmap(data.corr(), annot = True)
# Out:
# <Axes: >
