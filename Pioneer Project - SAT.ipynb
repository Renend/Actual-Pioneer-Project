# %%
# !pip install ydata-profiling

# %%
import pandas as pd
import ydata_profiling

df = pd.read_csv('Average SAT Scores  - Sheet1.csv')
pr = df.profile_report()
pr
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.7.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-06-25 03:24:51.409842&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Year                    52 non-null     int64
#  1   Math                    52 non-null     int64
#  2   Reading                 52 non-null     int64
#  3   Writing                 11 non-null     float64
#  4   Total (Math + Reading)  52 non-null     int64
# dtypes: float64(1), int64(4)
# memory usage: 2.2 KB

# %%
df.describe()
# Out:
#               Year        Math     Reading     Writing  Total (Math + Reading)
# count    52.000000   52.000000   52.000000   11.000000               52.000000
# mean   1997.500000  508.711538  507.903846  489.454545             1016.615385
# std      15.154757   10.548370   11.047597    4.321195               18.578032
# min    1972.000000  492.000000  494.000000  482.000000              994.000000
# 25%    1984.750000  500.750000  500.000000  487.500000             1003.000000
# 50%    1997.500000  508.500000  505.000000  489.000000             1010.500000
# 75%    2010.250000  514.000000  509.000000  492.500000             1022.250000
# max    2023.000000  531.000000  536.000000  497.000000             1067.000000

# %% [markdown]
# # EDA
# ## Univariate

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import style

sns.boxenplot(df['Total (Math + Reading)'])
plt.show()

# %%
sns.boxenplot(df['Math'])
plt.show()

# %%
sns.boxenplot(df['Reading'])
plt.show()

# %% [markdown]
# ## Bivariate

# %%
plt.scatter(df['Year'], df['Total (Math + Reading)'])
plt.show()

# %%
plt.plot(df['Year'], df['Total (Math + Reading)'])
plt.show()

# %% [markdown]
# ## Multivariate Analysis

# %%
import numpy as np
# %matplotlib inline

plt.figure(figsize=(10,5))
var = ['Year', 'Math', 'Reading', 'Total (Math + Reading)']
data = df[var]
sns.heatmap(data.corr(), annot = True)
# Out:
# <Axes: >
